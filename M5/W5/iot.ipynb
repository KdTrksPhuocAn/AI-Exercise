# %%
# !mkdir data/

# %%
# !gdown  1gzWOtABiVmJ38usCSDe5F9gR2tECt3zu -O data/
# !gdown  15lwipssmC_K82ukRfb0uVCiDH1TZ3QCf -O data/
# !gdown  1nIo1_wBmkovz-u_BCsV5c1Kbz6ZqoKwq -O data/
# !gdown  1ZteHYSgbuZu_GcUJHW8ZzoZv1DE8-oLw
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1gzWOtABiVmJ38usCSDe5F9gR2tECt3zu
# To: /content/data/landmark_val.csv
# 100% 369k/369k [00:00<00:00, 39.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=15lwipssmC_K82ukRfb0uVCiDH1TZ3QCf
# To: /content/data/landmark_train.csv
# 100% 1.28M/1.28M [00:00<00:00, 114MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1nIo1_wBmkovz-u_BCsV5c1Kbz6ZqoKwq
# To: /content/data/landmark_test.csv
# 100% 320k/320k [00:00<00:00, 72.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ZteHYSgbuZu_GcUJHW8ZzoZv1DE8-oLw
# To: /content/hand_gesture.yaml
# 100% 120/120 [00:00<00:00, 701kB/s]

# %%
# !pip install mediapipe==0.10.18
# Out:
# Collecting mediapipe==0.10.18
#   Downloading mediapipe-0.10.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (24.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (24.3.25)
# Requirement already satisfied: jax in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (0.4.33)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (0.4.33)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (3.8.0)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (4.25.5)
# Collecting sounddevice>=0.4.4 (from mediapipe==0.10.18)
#   Downloading sounddevice-0.5.1-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe==0.10.18) (1.17.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe==0.10.18) (0.4.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe==0.10.18) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe==0.10.18) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe==0.10.18) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe==0.10.18) (1.16.0)
# Downloading mediapipe-0.10.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.1/36.1 MB 53.7 MB/s eta 0:00:00
# Downloading sounddevice-0.5.1-py3-none-any.whl (32 kB)
# Installing collected packages: sounddevice, mediapipe
# Successfully installed mediapipe-0.10.18 sounddevice-0.5.1

# %%
# !pip install torchmetrics
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-1.6.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (24.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.5.1+cu121)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.11.9-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (75.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.2)
# Downloading torchmetrics-1.6.0-py3-none-any.whl (926 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 926.4/926.4 kB 34.2 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.9-py3-none-any.whl (28 kB)
# Installing collected packages: lightning-utilities, torchmetrics
# Successfully installed lightning-utilities-0.11.9 torchmetrics-1.6.0

# %%
import os
import cv2
import yaml
import torch
import numpy as np
import pandas as pd
from  torch import nn
import mediapipe as mp
from torch import optim
from datetime import datetime
from torchmetrics import Accuracy
from torch.utils.data import Dataset

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        list_label = label_dict_from_config_file("hand_gesture.yaml")
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(63, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(p=0.6),
            nn.Linear(128, len(list_label)),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

    def predict(self,x,threshold=0.8):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        chosen_ind = torch.argmax(softmax_prob,dim=1)
        return torch.where(softmax_prob[0,chosen_ind]>threshold,chosen_ind,-1)

    def predict_with_known_class(self,x):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        return torch.argmax(softmax_prob,dim=1)

    def score(self,logits):
        return -torch.amax(logits,dim=1)

# %%
def label_dict_from_config_file(relative_path):
    with open(relative_path,"r") as f:
       label_tag = yaml.full_load(f)["gestures"]
    return label_tag

# %%
class HandLandmarksDetector():
    def __init__(self) -> None:
        self.mp_drawing = mp.solutions.drawing_utils
        self.mp_drawing_styles = mp.solutions.drawing_styles
        self.mp_hands = mp.solutions.hands
        self.detector = self.mp_hands.Hands(False,max_num_hands=1,min_detection_confidence=0.5)

    def detectHand(self,frame):
        hands = []
        frame = cv2.flip(frame, 1)
        annotated_image = frame.copy()
        results = self.detector.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        if results.multi_hand_landmarks is not None:
            for hand_landmarks in results.multi_hand_landmarks:
                hand = []
                self.mp_drawing.draw_landmarks(
                    annotated_image,
                    hand_landmarks,
                    self.mp_hands.HAND_CONNECTIONS,
                    self.mp_drawing_styles.get_default_hand_landmarks_style(),
                    self.mp_drawing_styles.get_default_hand_connections_style())
                for landmark in hand_landmarks.landmark:
                    x,y,z = landmark.x,landmark.y,landmark.z
                    hand.extend([x,y,z])
            hands.append(hand)
        return hands,annotated_image

# %%
class CustomImageDataset(Dataset):
    def __init__(self, data_file):
        self.data = pd.read_csv(data_file)
        self.labels = torch.from_numpy(self.data.iloc[:,0].to_numpy())

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        one_hot_label = self.labels[idx]
        torch_data = torch.from_numpy(self.data.iloc[idx,1:].to_numpy(dtype=np.float32))
        return torch_data, one_hot_label

# %%
class EarlyStopper:
    def __init__(self, patience=1, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.watched_metrics = np.inf

    def early_stop(self, current_value):
        if current_value < self.watched_metrics:
            self.watched_metrics = current_value
            self.counter = 0
        elif current_value > (self.watched_metrics + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
def train(trainloader, val_loader, model, loss_function, early_stopper, optimizer):
    # add auroc score
    best_vloss = 1_000_000
    timestamp = datetime.now().strftime('%d-%m %H:%M')
    for epoch in range(300):
        #training step
        model.train(True)
        running_loss = 0.0
        acc_train = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for batch_number,data in enumerate(trainloader):
            inputs,labels = data
            optimizer.zero_grad()
            preds = model(inputs)
            loss = loss_function(preds,labels)
            loss.backward()
            optimizer.step()
            acc_train.update(model.predict_with_known_class(inputs), labels)
            running_loss += loss.item()
        avg_loss = running_loss / len(trainloader)
        # validating step
        model.train(False)
        running_vloss = 0.0
        acc_val = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for i, vdata in enumerate(val_loader):
            vinputs, vlabels = vdata
            preds = model(vinputs)
            vloss = loss_function(preds, vlabels)
            running_vloss += vloss.item()
            acc_val.update(model.predict_with_known_class(vinputs), vlabels)

        # Log the running loss averaged per batch
        # for both training and validation
        print(f"Epoch {epoch}: ")
        print(f"Accuracy train:{acc_train.compute().item()}, val:{acc_val.compute().item()}")
        avg_vloss = running_vloss / len(val_loader)
        print('LOSS train {} valid {}'.format(avg_loss, avg_vloss))
        print('Training vs. Validation Loss',
                        { 'Training' : avg_loss, 'Validation' : avg_vloss },
                        epoch + 1)
        print('Training vs. Validation accuracy',
                        { 'Training' : acc_train.compute().item()
                        , 'Validation' : acc_val.compute().item() },
                        epoch + 1)

        # Track best performance, and save the model's state
        if avg_vloss < best_vloss:
            best_vloss = avg_vloss
            best_model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_best'
            torch.save(model.state_dict(), best_model_path)
        if early_stopper.early_stop(avg_vloss):
            print(f"stopping at epoch {epoch}, minimum: {early_stopper.watched_metrics}")
            break

    model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_last'
    torch.save(model.state_dict(), model_path)

    print(acc_val.compute())
    return model, best_model_path

# %%
DATA_FOLDER_PATH="./data/"
LIST_LABEL = label_dict_from_config_file("hand_gesture.yaml")
train_path = os.path.join(DATA_FOLDER_PATH,"landmark_train.csv")
val_path = os.path.join(DATA_FOLDER_PATH,"landmark_val.csv")
save_path = './models'
os.makedirs(save_path,exist_ok=True)

trainset = CustomImageDataset(train_path)
trainloader = torch.utils.data.DataLoader(trainset,batch_size=40,shuffle=True)

valset = CustomImageDataset(os.path.join(val_path))
val_loader = torch.utils.data.DataLoader(valset,batch_size=50, shuffle=False)

model = NeuralNetwork()
loss_function = nn.CrossEntropyLoss()
early_stopper = EarlyStopper(patience=30,min_delta=0.01)
optimizer = optim.Adam(model.parameters(),lr=0.0001)

model, best_model_path = train(trainloader, val_loader, model, loss_function, early_stopper, optimizer)
# Out:
# Epoch 0:
# Accuracy train:0.21197251975536346, val:0.30034130811691284
# LOSS train 1.6056998876424937 valid 1.5958032409350078
# Training vs. Validation Loss {'Training': 1.6056998876424937, 'Validation': 1.5958032409350078} 1
# Training vs. Validation accuracy {'Training': 0.21197251975536346, 'Validation': 0.30034130811691284} 1
# Epoch 1:
# Accuracy train:0.28361138701438904, val:0.5153583884239197
# LOSS train 1.5885265607100267 valid 1.5727746486663818
# Training vs. Validation Loss {'Training': 1.5885265607100267, 'Validation': 1.5727746486663818} 2
# Training vs. Validation accuracy {'Training': 0.28361138701438904, 'Validation': 0.5153583884239197} 2
# Epoch 2:
# Accuracy train:0.3680078387260437, val:0.5085324048995972
# LOSS train 1.5666657640383794 valid 1.5529801448186238
# Training vs. Validation Loss {'Training': 1.5666657640383794, 'Validation': 1.5529801448186238} 3
# Training vs. Validation accuracy {'Training': 0.3680078387260437, 'Validation': 0.5085324048995972} 3
# Epoch 3:
# Accuracy train:0.43768399953842163, val:0.5494880676269531
# LOSS train 1.535465148779062 valid 1.5221903920173645
# Training vs. Validation Loss {'Training': 1.535465148779062, 'Validation': 1.5221903920173645} 4
# Training vs. Validation accuracy {'Training': 0.43768399953842163, 'Validation': 0.5494880676269531} 4
# Epoch 4:
# Accuracy train:0.49263983964920044, val:0.5460751056671143
# LOSS train 1.4896350640517015 valid 1.4564868410428364
# Training vs. Validation Loss {'Training': 1.4896350640517015, 'Validation': 1.4564868410428364} 5
# Training vs. Validation accuracy {'Training': 0.49263983964920044, 'Validation': 0.5460751056671143} 5
# Epoch 5:
# Accuracy train:0.5426889061927795, val:0.511945366859436
# LOSS train 1.407615684545957 valid 1.3717827399571736
# Training vs. Validation Loss {'Training': 1.407615684545957, 'Validation': 1.3717827399571736} 6
# Training vs. Validation accuracy {'Training': 0.5426889061927795, 'Validation': 0.511945366859436} 6
# Epoch 6:
# Accuracy train:0.5613346695899963, val:0.4505119323730469
# LOSS train 1.304586873604701 valid 1.2376091281572978
# Training vs. Validation Loss {'Training': 1.304586873604701, 'Validation': 1.2376091281572978} 7
# Training vs. Validation accuracy {'Training': 0.5613346695899963, 'Validation': 0.4505119323730469} 7
# Epoch 7:
# Accuracy train:0.5672227740287781, val:0.49146756529808044
# LOSS train 1.1701866342471197 valid 1.1182462771733601
# Training vs. Validation Loss {'Training': 1.1701866342471197, 'Validation': 1.1182462771733601} 8
# Training vs. Validation accuracy {'Training': 0.5672227740287781, 'Validation': 0.49146756529808044} 8
# Epoch 8:
# Accuracy train:0.6045142412185669, val:0.5153583884239197
# LOSS train 1.0307076435822706 valid 0.9988158419728279
# Training vs. Validation Loss {'Training': 1.0307076435822706, 'Validation': 0.9988158419728279} 9
# Training vs. Validation accuracy {'Training': 0.6045142412185669, 'Validation': 0.5153583884239197} 9
# Epoch 9:
# Accuracy train:0.6633954644203186, val:0.658703088760376
# LOSS train 0.9100215778901026 valid 0.8785205061237017
# Training vs. Validation Loss {'Training': 0.9100215778901026, 'Validation': 0.8785205061237017} 10
# Training vs. Validation accuracy {'Training': 0.6633954644203186, 'Validation': 0.658703088760376} 10
# Epoch 10:
# Accuracy train:0.7281648516654968, val:0.7406143546104431
# LOSS train 0.7975806341721461 valid 0.7488523970047632
# Training vs. Validation Loss {'Training': 0.7975806341721461, 'Validation': 0.7488523970047632} 11
# Training vs. Validation accuracy {'Training': 0.7281648516654968, 'Validation': 0.7406143546104431} 11
# Epoch 11:
# Accuracy train:0.7860647439956665, val:0.7986348271369934
# LOSS train 0.6765262117752662 valid 0.6246770769357681
# Training vs. Validation Loss {'Training': 0.6765262117752662, 'Validation': 0.6246770769357681} 12
# Training vs. Validation accuracy {'Training': 0.7860647439956665, 'Validation': 0.7986348271369934} 12
# Epoch 12:
# Accuracy train:0.828262984752655, val:0.7952218651771545
# LOSS train 0.5653447187863864 valid 0.5279308278113604
# Training vs. Validation Loss {'Training': 0.5653447187863864, 'Validation': 0.5279308278113604} 13
# Training vs. Validation accuracy {'Training': 0.828262984752655, 'Validation': 0.7952218651771545} 13
# Epoch 13:
# Accuracy train:0.8469087481498718, val:0.8361774682998657
# LOSS train 0.4949733144961871 valid 0.44304165927072364
# Training vs. Validation Loss {'Training': 0.4949733144961871, 'Validation': 0.44304165927072364} 14
# Training vs. Validation accuracy {'Training': 0.8469087481498718, 'Validation': 0.8361774682998657} 14
# Epoch 14:
# Accuracy train:0.8920510411262512, val:0.9726962447166443
# LOSS train 0.41854697236647975 valid 0.35530307454367477
# Training vs. Validation Loss {'Training': 0.41854697236647975, 'Validation': 0.35530307454367477} 15
# Training vs. Validation accuracy {'Training': 0.8920510411262512, 'Validation': 0.9726962447166443} 15
# Epoch 15:
# Accuracy train:0.915603518486023, val:0.979522168636322
# LOSS train 0.3450850758415002 valid 0.28751135307053727
# Training vs. Validation Loss {'Training': 0.3450850758415002, 'Validation': 0.28751135307053727} 16
# Training vs. Validation accuracy {'Training': 0.915603518486023, 'Validation': 0.979522168636322} 16
# Epoch 16:
# Accuracy train:0.9263984560966492, val:0.9897611141204834
# LOSS train 0.3213209005502554 valid 0.2222648976991574
# Training vs. Validation Loss {'Training': 0.3213209005502554, 'Validation': 0.2222648976991574} 17
# Training vs. Validation accuracy {'Training': 0.9263984560966492, 'Validation': 0.9897611141204834} 17
# Epoch 17:
# Accuracy train:0.9538763761520386, val:0.9897611141204834
# LOSS train 0.2557926533313898 valid 0.1794398872492214
# Training vs. Validation Loss {'Training': 0.2557926533313898, 'Validation': 0.1794398872492214} 18
# Training vs. Validation accuracy {'Training': 0.9538763761520386, 'Validation': 0.9897611141204834} 18
# Epoch 18:
# Accuracy train:0.965652585029602, val:0.9863481521606445
# LOSS train 0.22769173177389 valid 0.1416126045708855
# Training vs. Validation Loss {'Training': 0.22769173177389, 'Validation': 0.1416126045708855} 19
# Training vs. Validation accuracy {'Training': 0.965652585029602, 'Validation': 0.9863481521606445} 19
# Epoch 19:
# Accuracy train:0.9636898636817932, val:0.9897611141204834
# LOSS train 0.2070438827459629 valid 0.10695348881805937
# Training vs. Validation Loss {'Training': 0.2070438827459629, 'Validation': 0.10695348881805937} 20
# Training vs. Validation accuracy {'Training': 0.9636898636817932, 'Validation': 0.9897611141204834} 20
# Epoch 20:
# Accuracy train:0.9666339755058289, val:0.9897611141204834
# LOSS train 0.17406531308705991 valid 0.06925781435954075
# Training vs. Validation Loss {'Training': 0.17406531308705991, 'Validation': 0.06925781435954075} 21
# Training vs. Validation accuracy {'Training': 0.9666339755058289, 'Validation': 0.9897611141204834} 21
# Epoch 21:
# Accuracy train:0.9715407490730286, val:0.9931740760803223
# LOSS train 0.16327471457994902 valid 0.04699816221060852
# Training vs. Validation Loss {'Training': 0.16327471457994902, 'Validation': 0.04699816221060852} 22
# Training vs. Validation accuracy {'Training': 0.9715407490730286, 'Validation': 0.9931740760803223} 22
# Epoch 22:
# Accuracy train:0.9685966372489929, val:0.9931740760803223
# LOSS train 0.14302697004033968 valid 0.042048209928907454
# Training vs. Validation Loss {'Training': 0.14302697004033968, 'Validation': 0.042048209928907454} 23
# Training vs. Validation accuracy {'Training': 0.9685966372489929, 'Validation': 0.9931740760803223} 23
# Epoch 23:
# Accuracy train:0.9784101843833923, val:0.9931740760803223
# LOSS train 0.13235685874063235 valid 0.03759290233332043
# Training vs. Validation Loss {'Training': 0.13235685874063235, 'Validation': 0.03759290233332043} 24
# Training vs. Validation accuracy {'Training': 0.9784101843833923, 'Validation': 0.9931740760803223} 24
# Epoch 24:
# Accuracy train:0.9793915748596191, val:0.9897611141204834
# LOSS train 0.11376883920568687 valid 0.0350389632221777
# Training vs. Validation Loss {'Training': 0.11376883920568687, 'Validation': 0.0350389632221777} 25
# Training vs. Validation accuracy {'Training': 0.9793915748596191, 'Validation': 0.9897611141204834} 25
# Epoch 25:
# Accuracy train:0.981354296207428, val:0.9897611141204834
# LOSS train 0.09875613221755394 valid 0.03715192365537708
# Training vs. Validation Loss {'Training': 0.09875613221755394, 'Validation': 0.03715192365537708} 26
# Training vs. Validation accuracy {'Training': 0.981354296207428, 'Validation': 0.9897611141204834} 26
# Epoch 26:
# Accuracy train:0.9803729057312012, val:0.9931740760803223
# LOSS train 0.09577232613586463 valid 0.020170632109511644
# Training vs. Validation Loss {'Training': 0.09577232613586463, 'Validation': 0.020170632109511644} 27
# Training vs. Validation accuracy {'Training': 0.9803729057312012, 'Validation': 0.9931740760803223} 27
# Epoch 27:
# Accuracy train:0.9803729057312012, val:0.9897611141204834
# LOSS train 0.09138290061113927 valid 0.0245416534501904
# Training vs. Validation Loss {'Training': 0.09138290061113927, 'Validation': 0.0245416534501904} 28
# Training vs. Validation accuracy {'Training': 0.9803729057312012, 'Validation': 0.9897611141204834} 28
# Epoch 28:
# Accuracy train:0.9803729057312012, val:0.9931740760803223
# LOSS train 0.08309608303870146 valid 0.022447200133077178
# Training vs. Validation Loss {'Training': 0.08309608303870146, 'Validation': 0.022447200133077178} 29
# Training vs. Validation accuracy {'Training': 0.9803729057312012, 'Validation': 0.9931740760803223} 29
# Epoch 29:
# Accuracy train:0.9842983484268188, val:0.9897611141204834
# LOSS train 0.08254392495235571 valid 0.018433884596258093
# Training vs. Validation Loss {'Training': 0.08254392495235571, 'Validation': 0.018433884596258093} 30
# Training vs. Validation accuracy {'Training': 0.9842983484268188, 'Validation': 0.9897611141204834} 30
# Epoch 30:
# Accuracy train:0.983316957950592, val:0.9897611141204834
# LOSS train 0.07524533233103844 valid 0.01661448764692371
# Training vs. Validation Loss {'Training': 0.07524533233103844, 'Validation': 0.01661448764692371} 31
# Training vs. Validation accuracy {'Training': 0.983316957950592, 'Validation': 0.9897611141204834} 31
# Epoch 31:
# Accuracy train:0.98233562707901, val:0.9931740760803223
# LOSS train 0.08980948370523177 valid 0.017095600453709874
# Training vs. Validation Loss {'Training': 0.08980948370523177, 'Validation': 0.017095600453709874} 32
# Training vs. Validation accuracy {'Training': 0.98233562707901, 'Validation': 0.9931740760803223} 32
# Epoch 32:
# Accuracy train:0.9862610697746277, val:0.9897611141204834
# LOSS train 0.06821296134820351 valid 0.01740058856375981
# Training vs. Validation Loss {'Training': 0.06821296134820351, 'Validation': 0.01740058856375981} 33
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9897611141204834} 33
# Epoch 33:
# Accuracy train:0.981354296207428, val:0.9897611141204834
# LOSS train 0.0623931444894809 valid 0.012993052689125761
# Training vs. Validation Loss {'Training': 0.0623931444894809, 'Validation': 0.012993052689125761} 34
# Training vs. Validation accuracy {'Training': 0.981354296207428, 'Validation': 0.9897611141204834} 34
# Epoch 34:
# Accuracy train:0.9901864528656006, val:0.9897611141204834
# LOSS train 0.06216930186089415 valid 0.017892777437130764
# Training vs. Validation Loss {'Training': 0.06216930186089415, 'Validation': 0.017892777437130764} 35
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9897611141204834} 35
# Epoch 35:
# Accuracy train:0.9862610697746277, val:0.9931740760803223
# LOSS train 0.06803454308269116 valid 0.015993786180236686
# Training vs. Validation Loss {'Training': 0.06803454308269116, 'Validation': 0.015993786180236686} 36
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9931740760803223} 36
# Epoch 36:
# Accuracy train:0.9872424006462097, val:0.9897611141204834
# LOSS train 0.05624017294926139 valid 0.017237946320771396
# Training vs. Validation Loss {'Training': 0.05624017294926139, 'Validation': 0.017237946320771396} 37
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9897611141204834} 37
# Epoch 37:
# Accuracy train:0.9852796792984009, val:0.9897611141204834
# LOSS train 0.059228589614996545 valid 0.015400266276022498
# Training vs. Validation Loss {'Training': 0.059228589614996545, 'Validation': 0.015400266276022498} 38
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9897611141204834} 38
# Epoch 38:
# Accuracy train:0.981354296207428, val:0.9931740760803223
# LOSS train 0.06796742578108723 valid 0.020928754517323494
# Training vs. Validation Loss {'Training': 0.06796742578108723, 'Validation': 0.020928754517323494} 39
# Training vs. Validation accuracy {'Training': 0.981354296207428, 'Validation': 0.9931740760803223} 39
# Epoch 39:
# Accuracy train:0.983316957950592, val:0.9931740760803223
# LOSS train 0.06282326084776567 valid 0.02019448606855197
# Training vs. Validation Loss {'Training': 0.06282326084776567, 'Validation': 0.02019448606855197} 40
# Training vs. Validation accuracy {'Training': 0.983316957950592, 'Validation': 0.9931740760803223} 40
# Epoch 40:
# Accuracy train:0.9862610697746277, val:0.9931740760803223
# LOSS train 0.05939880919714387 valid 0.022041264312671654
# Training vs. Validation Loss {'Training': 0.05939880919714387, 'Validation': 0.022041264312671654} 41
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9931740760803223} 41
# Epoch 41:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.04261901430212534 valid 0.015937351619868423
# Training vs. Validation Loss {'Training': 0.04261901430212534, 'Validation': 0.015937351619868423} 42
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 42
# Epoch 42:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.05456773564219475 valid 0.014325888330252686
# Training vs. Validation Loss {'Training': 0.05456773564219475, 'Validation': 0.014325888330252686} 43
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 43
# Epoch 43:
# Accuracy train:0.9852796792984009, val:0.9931740760803223
# LOSS train 0.054010422685398504 valid 0.017761773019932054
# Training vs. Validation Loss {'Training': 0.054010422685398504, 'Validation': 0.017761773019932054} 44
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9931740760803223} 44
# Epoch 44:
# Accuracy train:0.9882237315177917, val:0.9897611141204834
# LOSS train 0.04862186337749545 valid 0.01491723646116346
# Training vs. Validation Loss {'Training': 0.04862186337749545, 'Validation': 0.01491723646116346} 45
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9897611141204834} 45
# Epoch 45:
# Accuracy train:0.9911677837371826, val:0.9897611141204834
# LOSS train 0.04957899313348417 valid 0.01382066727092024
# Training vs. Validation Loss {'Training': 0.04957899313348417, 'Validation': 0.01382066727092024} 46
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9897611141204834} 46
# Epoch 46:
# Accuracy train:0.9862610697746277, val:0.9931740760803223
# LOSS train 0.0518023688883449 valid 0.020201520560173474
# Training vs. Validation Loss {'Training': 0.0518023688883449, 'Validation': 0.020201520560173474} 47
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9931740760803223} 47
# Epoch 47:
# Accuracy train:0.9862610697746277, val:0.9931740760803223
# LOSS train 0.0510028599976347 valid 0.013388271080354267
# Training vs. Validation Loss {'Training': 0.0510028599976347, 'Validation': 0.013388271080354267} 48
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9931740760803223} 48
# Epoch 48:
# Accuracy train:0.9872424006462097, val:0.9897611141204834
# LOSS train 0.04122435715264426 valid 0.014243488902138779
# Training vs. Validation Loss {'Training': 0.04122435715264426, 'Validation': 0.014243488902138779} 49
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9897611141204834} 49
# Epoch 49:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.048500226255362995 valid 0.014769275852813735
# Training vs. Validation Loss {'Training': 0.048500226255362995, 'Validation': 0.014769275852813735} 50
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 50
# Epoch 50:
# Accuracy train:0.9862610697746277, val:0.9931740760803223
# LOSS train 0.04802069779879485 valid 0.01578487487010231
# Training vs. Validation Loss {'Training': 0.04802069779879485, 'Validation': 0.01578487487010231} 51
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9931740760803223} 51
# Epoch 51:
# Accuracy train:0.9882237315177917, val:0.9897611141204834
# LOSS train 0.05158950291717282 valid 0.013739217562639775
# Training vs. Validation Loss {'Training': 0.05158950291717282, 'Validation': 0.013739217562639775} 52
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9897611141204834} 52
# Epoch 52:
# Accuracy train:0.9882237315177917, val:0.9897611141204834
# LOSS train 0.041419773774508103 valid 0.018029123112986174
# Training vs. Validation Loss {'Training': 0.041419773774508103, 'Validation': 0.018029123112986174} 53
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9897611141204834} 53
# Epoch 53:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.03222627687053038 valid 0.01539163427666305
# Training vs. Validation Loss {'Training': 0.03222627687053038, 'Validation': 0.01539163427666305} 54
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9965870380401611} 54
# Epoch 54:
# Accuracy train:0.9862610697746277, val:0.9897611141204834
# LOSS train 0.06854773583248831 valid 0.017083766384833627
# Training vs. Validation Loss {'Training': 0.06854773583248831, 'Validation': 0.017083766384833627} 55
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9897611141204834} 55
# Epoch 55:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.03966068354650186 valid 0.02093721510573232
# Training vs. Validation Loss {'Training': 0.03966068354650186, 'Validation': 0.02093721510573232} 56
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 56
# Epoch 56:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.04167603368226152 valid 0.014356089166540187
# Training vs. Validation Loss {'Training': 0.04167603368226152, 'Validation': 0.014356089166540187} 57
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 57
# Epoch 57:
# Accuracy train:0.9872424006462097, val:0.9931740760803223
# LOSS train 0.04739110181645419 valid 0.014229882282961626
# Training vs. Validation Loss {'Training': 0.04739110181645419, 'Validation': 0.014229882282961626} 58
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9931740760803223} 58
# Epoch 58:
# Accuracy train:0.9872424006462097, val:0.9965870380401611
# LOSS train 0.0402706703171134 valid 0.012905874613049187
# Training vs. Validation Loss {'Training': 0.0402706703171134, 'Validation': 0.012905874613049187} 59
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9965870380401611} 59
# Epoch 59:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.031183153856545687 valid 0.012715905080161368
# Training vs. Validation Loss {'Training': 0.031183153856545687, 'Validation': 0.012715905080161368} 60
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 60
# Epoch 60:
# Accuracy train:0.9901864528656006, val:0.9965870380401611
# LOSS train 0.0436100614651178 valid 0.012042096591054966
# Training vs. Validation Loss {'Training': 0.0436100614651178, 'Validation': 0.012042096591054966} 61
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9965870380401611} 61
# Epoch 61:
# Accuracy train:0.9852796792984009, val:0.9931740760803223
# LOSS train 0.037845874044041224 valid 0.011691664552169337
# Training vs. Validation Loss {'Training': 0.037845874044041224, 'Validation': 0.011691664552169337} 62
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9931740760803223} 62
# Epoch 62:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.03694389133642499 valid 0.013365374565485885
# Training vs. Validation Loss {'Training': 0.03694389133642499, 'Validation': 0.013365374565485885} 63
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 63
# Epoch 63:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.03344002306067313 valid 0.0103161287253594
# Training vs. Validation Loss {'Training': 0.03344002306067313, 'Validation': 0.0103161287253594} 64
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 64
# Epoch 64:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.04120342420020069 valid 0.015772319433229615
# Training vs. Validation Loss {'Training': 0.04120342420020069, 'Validation': 0.015772319433229615} 65
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 65
# Epoch 65:
# Accuracy train:0.9921491742134094, val:0.9965870380401611
# LOSS train 0.03194935859825749 valid 0.012169539489377712
# Training vs. Validation Loss {'Training': 0.03194935859825749, 'Validation': 0.012169539489377712} 66
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9965870380401611} 66
# Epoch 66:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.03834964526602282 valid 0.016145576394592354
# Training vs. Validation Loss {'Training': 0.03834964526602282, 'Validation': 0.016145576394592354} 67
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 67
# Epoch 67:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.04144088712592538 valid 0.01417491400191769
# Training vs. Validation Loss {'Training': 0.04144088712592538, 'Validation': 0.01417491400191769} 68
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 68
# Epoch 68:
# Accuracy train:0.9901864528656006, val:0.9965870380401611
# LOSS train 0.041320017592694894 valid 0.014230045655494905
# Training vs. Validation Loss {'Training': 0.041320017592694894, 'Validation': 0.014230045655494905} 69
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9965870380401611} 69
# Epoch 69:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.04235773598058866 valid 0.011925870587219833
# Training vs. Validation Loss {'Training': 0.04235773598058866, 'Validation': 0.011925870587219833} 70
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 70
# Epoch 70:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.029557935759210244 valid 0.014665202189917181
# Training vs. Validation Loss {'Training': 0.029557935759210244, 'Validation': 0.014665202189917181} 71
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 71
# Epoch 71:
# Accuracy train:0.9921491742134094, val:0.9965870380401611
# LOSS train 0.03888038801960647 valid 0.01226935124289715
# Training vs. Validation Loss {'Training': 0.03888038801960647, 'Validation': 0.01226935124289715} 72
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9965870380401611} 72
# Epoch 72:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.029420141737388734 valid 0.0157262327833602
# Training vs. Validation Loss {'Training': 0.029420141737388734, 'Validation': 0.0157262327833602} 73
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 73
# Epoch 73:
# Accuracy train:0.9892051219940186, val:0.9965870380401611
# LOSS train 0.03513062265343391 valid 0.009506426296866266
# Training vs. Validation Loss {'Training': 0.03513062265343391, 'Validation': 0.009506426296866266} 74
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9965870380401611} 74
# Epoch 74:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.03571506969344158 valid 0.015649514633272094
# Training vs. Validation Loss {'Training': 0.03571506969344158, 'Validation': 0.015649514633272094} 75
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 75
# Epoch 75:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.029568045335159134 valid 0.015840370288970007
# Training vs. Validation Loss {'Training': 0.029568045335159134, 'Validation': 0.015840370288970007} 76
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 76
# Epoch 76:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.03523223106570255 valid 0.016779931926597175
# Training vs. Validation Loss {'Training': 0.03523223106570255, 'Validation': 0.016779931926597175} 77
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 77
# Epoch 77:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.05181606286742653 valid 0.017427350894536175
# Training vs. Validation Loss {'Training': 0.05181606286742653, 'Validation': 0.017427350894536175} 78
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 78
# Epoch 78:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.03720577555493666 valid 0.013733111083790087
# Training vs. Validation Loss {'Training': 0.03720577555493666, 'Validation': 0.013733111083790087} 79
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 79
# Epoch 79:
# Accuracy train:0.9970559477806091, val:0.9965870380401611
# LOSS train 0.028014941821591213 valid 0.01401651744663468
# Training vs. Validation Loss {'Training': 0.028014941821591213, 'Validation': 0.01401651744663468} 80
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9965870380401611} 80
# Epoch 80:
# Accuracy train:0.9911677837371826, val:0.9863481521606445
# LOSS train 0.04221585521008819 valid 0.029051339633648848
# Training vs. Validation Loss {'Training': 0.04221585521008819, 'Validation': 0.029051339633648848} 81
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9863481521606445} 81
# Epoch 81:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.038926576174652346 valid 0.011832301136867803
# Training vs. Validation Loss {'Training': 0.038926576174652346, 'Validation': 0.011832301136867803} 82
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 82
# Epoch 82:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.032529713335232094 valid 0.0150371273972875
# Training vs. Validation Loss {'Training': 0.032529713335232094, 'Validation': 0.0150371273972875} 83
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 83
# Epoch 83:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.03308466072373379 valid 0.016784706108865066
# Training vs. Validation Loss {'Training': 0.03308466072373379, 'Validation': 0.016784706108865066} 84
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 84
# Epoch 84:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.03805501955167319 valid 0.015577641600051114
# Training vs. Validation Loss {'Training': 0.03805501955167319, 'Validation': 0.015577641600051114} 85
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 85
# Epoch 85:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.024897683734217517 valid 0.01519232872245387
# Training vs. Validation Loss {'Training': 0.024897683734217517, 'Validation': 0.01519232872245387} 86
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 86
# Epoch 86:
# Accuracy train:0.9931305050849915, val:0.9965870380401611
# LOSS train 0.02397920410686101 valid 0.014444909642406856
# Training vs. Validation Loss {'Training': 0.02397920410686101, 'Validation': 0.014444909642406856} 87
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9965870380401611} 87
# Epoch 87:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.03672807571442368 valid 0.010756120796334775
# Training vs. Validation Loss {'Training': 0.03672807571442368, 'Validation': 0.010756120796334775} 88
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 88
# Epoch 88:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.030030201350410398 valid 0.014905112568006492
# Training vs. Validation Loss {'Training': 0.030030201350410398, 'Validation': 0.014905112568006492} 89
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 89
# Epoch 89:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.016204149623473104 valid 0.010366065515502973
# Training vs. Validation Loss {'Training': 0.016204149623473104, 'Validation': 0.010366065515502973} 90
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 90
# Epoch 90:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.028055616636545613 valid 0.014988252100844571
# Training vs. Validation Loss {'Training': 0.028055616636545613, 'Validation': 0.014988252100844571} 91
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 91
# Epoch 91:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.02151151479427846 valid 0.014227396589528022
# Training vs. Validation Loss {'Training': 0.02151151479427846, 'Validation': 0.014227396589528022} 92
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 92
# Epoch 92:
# Accuracy train:0.9911677837371826, val:0.9965870380401611
# LOSS train 0.03538663673680276 valid 0.013229164406122132
# Training vs. Validation Loss {'Training': 0.03538663673680276, 'Validation': 0.013229164406122132} 93
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9965870380401611} 93
# Epoch 93:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.017265692469663918 valid 0.014742691673215328
# Training vs. Validation Loss {'Training': 0.017265692469663918, 'Validation': 0.014742691673215328} 94
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 94
# Epoch 94:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.017242535760697838 valid 0.013956141111634679
# Training vs. Validation Loss {'Training': 0.017242535760697838, 'Validation': 0.013956141111634679} 95
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 95
# Epoch 95:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.0251884837455761 valid 0.01868331125479017
# Training vs. Validation Loss {'Training': 0.0251884837455761, 'Validation': 0.01868331125479017} 96
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 96
# Epoch 96:
# Accuracy train:0.9921491742134094, val:0.9965870380401611
# LOSS train 0.019225264908387683 valid 0.013734108644750146
# Training vs. Validation Loss {'Training': 0.019225264908387683, 'Validation': 0.013734108644750146} 97
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9965870380401611} 97
# Epoch 97:
# Accuracy train:0.9931305050849915, val:0.9965870380401611
# LOSS train 0.030299152149102435 valid 0.014803518061493529
# Training vs. Validation Loss {'Training': 0.030299152149102435, 'Validation': 0.014803518061493529} 98
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9965870380401611} 98
# Epoch 98:
# Accuracy train:0.9921491742134094, val:0.9897611141204834
# LOSS train 0.028365346885178812 valid 0.014473756843131014
# Training vs. Validation Loss {'Training': 0.028365346885178812, 'Validation': 0.014473756843131014} 99
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9897611141204834} 99
# Epoch 99:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.02705617423634976 valid 0.010937167274960302
# Training vs. Validation Loss {'Training': 0.02705617423634976, 'Validation': 0.010937167274960302} 100
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9965870380401611} 100
# Epoch 100:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.018861851319133375 valid 0.013110934568430821
# Training vs. Validation Loss {'Training': 0.018861851319133375, 'Validation': 0.013110934568430821} 101
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9965870380401611} 101
# Epoch 101:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.027025190808881935 valid 0.013697801235593943
# Training vs. Validation Loss {'Training': 0.027025190808881935, 'Validation': 0.013697801235593943} 102
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 102
# Epoch 102:
# Accuracy train:0.9901864528656006, val:0.9965870380401611
# LOSS train 0.02155020498097516 valid 0.014056540206145959
# Training vs. Validation Loss {'Training': 0.02155020498097516, 'Validation': 0.014056540206145959} 103
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9965870380401611} 103
# Epoch 103:
# Accuracy train:0.9970559477806091, val:0.9897611141204834
# LOSS train 0.03027610686303188 valid 0.02106978524147962
# Training vs. Validation Loss {'Training': 0.03027610686303188, 'Validation': 0.02106978524147962} 104
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9897611141204834} 104
# Epoch 104:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.015523734692788612 valid 0.016926673488948534
# Training vs. Validation Loss {'Training': 0.015523734692788612, 'Validation': 0.016926673488948534} 105
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 105
# Epoch 105:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.028483173496519718 valid 0.02004293249857862
# Training vs. Validation Loss {'Training': 0.028483173496519718, 'Validation': 0.02004293249857862} 106
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 106
# Epoch 106:
# Accuracy train:0.9921491742134094, val:0.9897611141204834
# LOSS train 0.03440600686455862 valid 0.02573928360368427
# Training vs. Validation Loss {'Training': 0.03440600686455862, 'Validation': 0.02573928360368427} 107
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9897611141204834} 107
# Epoch 107:
# Accuracy train:0.9960745573043823, val:0.9897611141204834
# LOSS train 0.024918970266858544 valid 0.01607388725869896
# Training vs. Validation Loss {'Training': 0.024918970266858544, 'Validation': 0.01607388725869896} 108
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9897611141204834} 108
# Epoch 108:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.025935089802190375 valid 0.01596763931896324
# Training vs. Validation Loss {'Training': 0.025935089802190375, 'Validation': 0.01596763931896324} 109
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 109
# Epoch 109:
# Accuracy train:0.9941118955612183, val:0.9863481521606445
# LOSS train 0.02771958378322709 valid 0.019673857425023773
# Training vs. Validation Loss {'Training': 0.02771958378322709, 'Validation': 0.019673857425023773} 110
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9863481521606445} 110
# Epoch 110:
# Accuracy train:0.9950932264328003, val:0.9863481521606445
# LOSS train 0.015286669063453492 valid 0.018910192809016735
# Training vs. Validation Loss {'Training': 0.015286669063453492, 'Validation': 0.018910192809016735} 111
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9863481521606445} 111
# Epoch 111:
# Accuracy train:0.9960745573043823, val:0.9897611141204834
# LOSS train 0.029745321411890194 valid 0.01992965537620724
# Training vs. Validation Loss {'Training': 0.029745321411890194, 'Validation': 0.01992965537620724} 112
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9897611141204834} 112
# Epoch 112:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.03237581780950467 valid 0.019626663063794087
# Training vs. Validation Loss {'Training': 0.03237581780950467, 'Validation': 0.019626663063794087} 113
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 113
# Epoch 113:
# Accuracy train:0.9931305050849915, val:0.9965870380401611
# LOSS train 0.027878262236929283 valid 0.018105280708823557
# Training vs. Validation Loss {'Training': 0.027878262236929283, 'Validation': 0.018105280708823557} 114
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9965870380401611} 114
# Epoch 114:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.02634896378283604 valid 0.017217916302494512
# Training vs. Validation Loss {'Training': 0.02634896378283604, 'Validation': 0.017217916302494512} 115
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 115
# Epoch 115:
# Accuracy train:0.9911677837371826, val:0.9897611141204834
# LOSS train 0.0327232187667575 valid 0.021266823466400336
# Training vs. Validation Loss {'Training': 0.0327232187667575, 'Validation': 0.021266823466400336} 116
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9897611141204834} 116
# Epoch 116:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.02806323821334025 valid 0.020807900338771407
# Training vs. Validation Loss {'Training': 0.02806323821334025, 'Validation': 0.020807900338771407} 117
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 117
# Epoch 117:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.019110589091164563 valid 0.019329665212429365
# Training vs. Validation Loss {'Training': 0.019110589091164563, 'Validation': 0.019329665212429365} 118
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 118
# Epoch 118:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.022617980739316687 valid 0.023507242913486454
# Training vs. Validation Loss {'Training': 0.022617980739316687, 'Validation': 0.023507242913486454} 119
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 119
# Epoch 119:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.028290223446674645 valid 0.023052312039605265
# Training vs. Validation Loss {'Training': 0.028290223446674645, 'Validation': 0.023052312039605265} 120
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 120
# Epoch 120:
# Accuracy train:0.9941118955612183, val:0.9829351305961609
# LOSS train 0.0291975021111564 valid 0.03818765541598168
# Training vs. Validation Loss {'Training': 0.0291975021111564, 'Validation': 0.03818765541598168} 121
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9829351305961609} 121
# Epoch 121:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.024770333113757752 valid 0.018894803543616945
# Training vs. Validation Loss {'Training': 0.024770333113757752, 'Validation': 0.018894803543616945} 122
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 122
# Epoch 122:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.01613388062217452 valid 0.022356592530248538
# Training vs. Validation Loss {'Training': 0.01613388062217452, 'Validation': 0.022356592530248538} 123
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 123
# Epoch 123:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.015884752850979567 valid 0.021809932709440243
# Training vs. Validation Loss {'Training': 0.015884752850979567, 'Validation': 0.021809932709440243} 124
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 124
# Epoch 124:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.022170586036876418 valid 0.020888286320636478
# Training vs. Validation Loss {'Training': 0.022170586036876418, 'Validation': 0.020888286320636478} 125
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 125
# Epoch 125:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.026313777251813848 valid 0.0253391057391165
# Training vs. Validation Loss {'Training': 0.026313777251813848, 'Validation': 0.0253391057391165} 126
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 126
# Epoch 126:
# Accuracy train:0.9921491742134094, val:0.9897611141204834
# LOSS train 0.0176058767336564 valid 0.03533431366827244
# Training vs. Validation Loss {'Training': 0.0176058767336564, 'Validation': 0.03533431366827244} 127
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9897611141204834} 127
# Epoch 127:
# Accuracy train:0.9921491742134094, val:0.9897611141204834
# LOSS train 0.025219186670325983 valid 0.025066807122243517
# Training vs. Validation Loss {'Training': 0.025219186670325983, 'Validation': 0.025066807122243517} 128
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9897611141204834} 128
# Epoch 128:
# Accuracy train:0.9960745573043823, val:0.9897611141204834
# LOSS train 0.02097510019890391 valid 0.026507609007486128
# Training vs. Validation Loss {'Training': 0.02097510019890391, 'Validation': 0.026507609007486128} 129
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9897611141204834} 129
# Epoch 129:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.01808521305121338 valid 0.03326327640688002
# Training vs. Validation Loss {'Training': 0.01808521305121338, 'Validation': 0.03326327640688002} 130
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 130
# Epoch 130:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.023570304543961987 valid 0.026798566588089063
# Training vs. Validation Loss {'Training': 0.023570304543961987, 'Validation': 0.026798566588089063} 131
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 131
# Epoch 131:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.01941070146410941 valid 0.02589180996430211
# Training vs. Validation Loss {'Training': 0.01941070146410941, 'Validation': 0.02589180996430211} 132
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 132
# Epoch 132:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.01891476301422629 valid 0.02337025400811399
# Training vs. Validation Loss {'Training': 0.01891476301422629, 'Validation': 0.02337025400811399} 133
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 133
# Epoch 133:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.015691935187742975 valid 0.03355491905551844
# Training vs. Validation Loss {'Training': 0.015691935187742975, 'Validation': 0.03355491905551844} 134
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 134
# Epoch 134:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.017416477330978244 valid 0.029196481493462063
# Training vs. Validation Loss {'Training': 0.017416477330978244, 'Validation': 0.029196481493462063} 135
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 135
# Epoch 135:
# Accuracy train:0.9970559477806091, val:0.9931740760803223
# LOSS train 0.012568807376038212 valid 0.02911116206180016
# Training vs. Validation Loss {'Training': 0.012568807376038212, 'Validation': 0.02911116206180016} 136
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9931740760803223} 136
# Epoch 136:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.012937570953419289 valid 0.03011002316933779
# Training vs. Validation Loss {'Training': 0.012937570953419289, 'Validation': 0.03011002316933779} 137
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 137
# Epoch 137:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.011421427851578651 valid 0.026896016255288185
# Training vs. Validation Loss {'Training': 0.011421427851578651, 'Validation': 0.026896016255288185} 138
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 138
# Epoch 138:
# Accuracy train:0.9950932264328003, val:0.9863481521606445
# LOSS train 0.014420301689264866 valid 0.030192098701869934
# Training vs. Validation Loss {'Training': 0.014420301689264866, 'Validation': 0.030192098701869934} 139
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9863481521606445} 139
# Epoch 139:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.031260029542653896 valid 0.03015979464752642
# Training vs. Validation Loss {'Training': 0.031260029542653896, 'Validation': 0.03015979464752642} 140
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 140
# stopping at epoch 139, minimum: 0.009506426296866266
# tensor(0.9898)

# %%
list_label = label_dict_from_config_file("hand_gesture.yaml")
DATA_FOLDER_PATH="./data/"
testset = CustomImageDataset(os.path.join(DATA_FOLDER_PATH,"landmark_test.csv"))
test_loader = torch.utils.data.DataLoader(testset,batch_size=20,shuffle=False)

network = NeuralNetwork()
network.load_state_dict(torch.load(best_model_path, weights_only=False))

network.eval()
acc_test = Accuracy(num_classes=len(list_label), task='MULTICLASS')
for i, test_data in enumerate(test_loader):
    test_input, test_label = test_data
    preds = network(test_input)
    acc_test.update(preds, test_label)
print(network.__class__.__name__)
print(f"Accuracy of model:{acc_test.compute().item()}")
print("========================================================================")
# Out:
# NeuralNetwork
# Accuracy of model:0.9724409580230713
# ========================================================================
